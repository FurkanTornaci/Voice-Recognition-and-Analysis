# %% [markdown]
# # Voice Activity

# %%
import os
import librosa
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Flatten, Dropout, Activation, Conv1D, MaxPooling1D, Dense
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# %% [markdown]
# ### Relative Path

# %%
cur_path = os.getcwd()

# %% [markdown]
# # 1. Read Sample File

# %%
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
recordNames = os.listdir("./ses/")
SampleNumbers = {}
recordNames.remove('.DS_Store')

# %%
recordDatasets = {}
numberOfSamples = []
for recordName in recordNames:
    path_0 = os.path.relpath(f'./ses/{recordName}/samples_0', cur_path)
    path_1 = os.path.relpath(f'./ses/{recordName}/samples_1', cur_path)
    AudioFiles_0 = [f for f in os.listdir(path_0) if os.path.isfile(os.path.join(path_0, f))]
    AudioFiles_1 = [f for f in os.listdir(path_1) if os.path.isfile(os.path.join(path_1, f))]
    SampleNumbers[recordName] = {
        "Child" : len(AudioFiles_1),
        "NonChild" : len(AudioFiles_0)
    }
    features = []
    labels = []
    n = min(len(AudioFiles_0), len(AudioFiles_1))
    selectedSamples_0 = random.sample(AudioFiles_0, n)
    selectedSamples_1 = random.sample(AudioFiles_1, n)
    for i in range(n):
        features.append(features_extractor(path_0 + "/" + selectedSamples_0[i]))
        labels.append(0)
        features.append(features_extractor(path_1 + "/" + selectedSamples_1[i]))
        labels.append(1)
    print(f"Dataset: {recordName} Number of Samples: {len(labels)}")
    recordDatasets[f"{recordName}"] = {
        "features" : features,
        "labels" : labels
    }
    numberOfSamples.append(len(labels))
# Out:
# Dataset: ENG Number of Samples: 0
# Dataset: 4CH072I Number of Samples: 722
# Dataset: 4CH071I Number of Samples: 218
# Dataset: 4CH069I Number of Samples: 1106
# Dataset: 4CH067I Number of Samples: 858
# Dataset: MAAP3 Number of Samples: 2184
# Dataset: MAAP5 Number of Samples: 2222
# Dataset: MAAP2 Number of Samples: 1964
# Dataset: 4CH065I Number of Samples: 976
# Dataset: 4CH066I Number of Samples: 4544
# Dataset: 4CH068I Number of Samples: 3696
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/hh/9lxcbb5x027_6w6mhndnkq580000gn/T/ipykernel_26808/55926308.py in <module>
#      16     selectedSamples_1 = random.sample(AudioFiles_1, n)
#      17     for i in range(n):
# ---> 18         features.append(features_extractor(path_0 + "/" + selectedSamples_0[i]))
#      19         labels.append(0)
#      20         features.append(features_extractor(path_1 + "/" + selectedSamples_1[i]))
#
# /var/folders/hh/9lxcbb5x027_6w6mhndnkq580000gn/T/ipykernel_26808/2583621025.py in features_extractor(file_name)
#       1 def features_extractor(file_name):
# ----> 2     audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast')
#       3     mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
#       4     mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
#       5
#
# /opt/anaconda3/envs/EMBOA/lib/python3.7/site-packages/librosa/util/decorators.py in inner_f(*args, **kwargs)
#      86             extra_args = len(args) - len(all_args)
#      87             if extra_args <= 0:
# ---> 88                 return f(*args, **kwargs)
#      89
#      90             # extra_args > 0
#
# /opt/anaconda3/envs/EMBOA/lib/python3.7/site-packages/librosa/core/audio.py in load(path, sr, mono, offset, duration, dtype, res_type)
#     166
#     167             # Load the target number of frames, and transpose to match librosa form
# --> 168             y = sf_desc.read(frames=frame_duration, dtype=dtype, always_2d=False).T
#     169
#     170     except RuntimeError as exc:
#
# /opt/anaconda3/envs/EMBOA/lib/python3.7/site-packages/soundfile.py in read(self, frames, dtype, always_2d, fill_value, out)
#     865             if frames < 0 or frames > len(out):
#     866                 frames = len(out)
# --> 867         frames = self._array_io('read', out, frames)
#     868         if len(out) > frames:
#     869             if fill_value is None:
#
# /opt/anaconda3/envs/EMBOA/lib/python3.7/site-packages/soundfile.py in _array_io(self, action, array, frames)
#    1310         assert array.dtype.itemsize == _ffi.sizeof(ctype)
#    1311         cdata = _ffi.cast(ctype + '*', array.__array_interface__['data'][0])
# -> 1312         return self._cdata_io(action, cdata, ctype, frames)
#    1313
#    1314     def _cdata_io(self, action, data, ctype, frames):
#
# /opt/anaconda3/envs/EMBOA/lib/python3.7/site-packages/soundfile.py in _cdata_io(self, action, data, ctype, frames)
#    1319             curr = self.tell()
#    1320         func = getattr(_snd, 'sf_' + action + 'f_' + ctype)
# -> 1321         frames = func(self._file, data, frames)
#    1322         _error_check(self._errorcode)
#    1323         if self.seekable():
#
# KeyboardInterrupt:

# %%
X, y = [], []
for recordName in recordNames:
    X.extend(recordDatasets[recordName]['features'])
    y.extend(recordDatasets[recordName]['labels'])
X = np.array(X)
y = np.array(y)

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
## Trianing my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 150
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/150
# 550/563 [============================>.] - ETA: 0s - loss: 3.5319 - accuracy: 0.5189
# Epoch 1: val_loss improved from inf to 0.67834, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 3.4679 - accuracy: 0.5182 - val_loss: 0.6783 - val_accuracy: 0.6217
# Epoch 2/150
# 542/563 [===========================>..] - ETA: 0s - loss: 0.7170 - accuracy: 0.5496
# Epoch 2: val_loss improved from 0.67834 to 0.67436, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.7164 - accuracy: 0.5505 - val_loss: 0.6744 - val_accuracy: 0.6419
# Epoch 3/150
# 539/563 [===========================>..] - ETA: 0s - loss: 0.6872 - accuracy: 0.5702
# Epoch 3: val_loss improved from 0.67436 to 0.64170, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.6861 - accuracy: 0.5721 - val_loss: 0.6417 - val_accuracy: 0.6969
# Epoch 4/150
# 530/563 [===========================>..] - ETA: 0s - loss: 0.6654 - accuracy: 0.5992
# Epoch 4: val_loss improved from 0.64170 to 0.61353, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.6644 - accuracy: 0.6006 - val_loss: 0.6135 - val_accuracy: 0.7234
# Epoch 5/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.6159 - accuracy: 0.6628
# Epoch 5: val_loss improved from 0.61353 to 0.50333, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.6127 - accuracy: 0.6654 - val_loss: 0.5033 - val_accuracy: 0.7547
# Epoch 6/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.5675 - accuracy: 0.7091
# Epoch 6: val_loss improved from 0.50333 to 0.50216, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.5680 - accuracy: 0.7092 - val_loss: 0.5022 - val_accuracy: 0.7744
# Epoch 7/150
# 521/563 [==========================>...] - ETA: 0s - loss: 0.5373 - accuracy: 0.7297
# Epoch 7: val_loss improved from 0.50216 to 0.45863, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7310 - val_loss: 0.4586 - val_accuracy: 0.7846
# Epoch 8/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.5211 - accuracy: 0.7451
# Epoch 8: val_loss improved from 0.45863 to 0.44172, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.5211 - accuracy: 0.7450 - val_loss: 0.4417 - val_accuracy: 0.8048
# Epoch 9/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.4951 - accuracy: 0.7663
# Epoch 9: val_loss did not improve from 0.44172
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4957 - accuracy: 0.7661 - val_loss: 0.4433 - val_accuracy: 0.8091
# Epoch 10/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.4825 - accuracy: 0.7791
# Epoch 10: val_loss did not improve from 0.44172
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4826 - accuracy: 0.7791 - val_loss: 0.4440 - val_accuracy: 0.8139
# Epoch 11/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.4749 - accuracy: 0.7878
# Epoch 11: val_loss improved from 0.44172 to 0.41839, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4758 - accuracy: 0.7870 - val_loss: 0.4184 - val_accuracy: 0.8222
# Epoch 12/150
# 539/563 [===========================>..] - ETA: 0s - loss: 0.4514 - accuracy: 0.7952
# Epoch 12: val_loss improved from 0.41839 to 0.41483, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4519 - accuracy: 0.7949 - val_loss: 0.4148 - val_accuracy: 0.8315
# Epoch 13/150
# 536/563 [===========================>..] - ETA: 0s - loss: 0.4484 - accuracy: 0.7989
# Epoch 13: val_loss improved from 0.41483 to 0.40648, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4493 - accuracy: 0.7988 - val_loss: 0.4065 - val_accuracy: 0.8359
# Epoch 14/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.4400 - accuracy: 0.8058
# Epoch 14: val_loss improved from 0.40648 to 0.40484, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4393 - accuracy: 0.8058 - val_loss: 0.4048 - val_accuracy: 0.8248
# Epoch 15/150
# 555/563 [============================>.] - ETA: 0s - loss: 0.4324 - accuracy: 0.8082
# Epoch 15: val_loss did not improve from 0.40484
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4324 - accuracy: 0.8081 - val_loss: 0.4053 - val_accuracy: 0.8364
# Epoch 16/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.4252 - accuracy: 0.8154
# Epoch 16: val_loss did not improve from 0.40484
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4253 - accuracy: 0.8153 - val_loss: 0.4086 - val_accuracy: 0.8321
# Epoch 17/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.4199 - accuracy: 0.8191
# Epoch 17: val_loss did not improve from 0.40484
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4219 - accuracy: 0.8186 - val_loss: 0.4197 - val_accuracy: 0.8395
# Epoch 18/150
# 534/563 [===========================>..] - ETA: 0s - loss: 0.4187 - accuracy: 0.8188
# Epoch 18: val_loss improved from 0.40484 to 0.38874, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.4170 - accuracy: 0.8193 - val_loss: 0.3887 - val_accuracy: 0.8373
# Epoch 19/150
# 555/563 [============================>.] - ETA: 0s - loss: 0.4142 - accuracy: 0.8213
# Epoch 19: val_loss did not improve from 0.38874
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4145 - accuracy: 0.8214 - val_loss: 0.4066 - val_accuracy: 0.8346
# Epoch 20/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.4061 - accuracy: 0.8219
# Epoch 20: val_loss did not improve from 0.38874
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4063 - accuracy: 0.8218 - val_loss: 0.4117 - val_accuracy: 0.8337
# Epoch 21/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.4071 - accuracy: 0.8218
# Epoch 21: val_loss did not improve from 0.38874
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4077 - accuracy: 0.8216 - val_loss: 0.4355 - val_accuracy: 0.8337
# Epoch 22/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.4033 - accuracy: 0.8261
# Epoch 22: val_loss improved from 0.38874 to 0.38375, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4041 - accuracy: 0.8258 - val_loss: 0.3837 - val_accuracy: 0.8375
# Epoch 23/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.4023 - accuracy: 0.8254
# Epoch 23: val_loss did not improve from 0.38375
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4023 - accuracy: 0.8261 - val_loss: 0.4190 - val_accuracy: 0.8217
# Epoch 24/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3979 - accuracy: 0.8266
# Epoch 24: val_loss did not improve from 0.38375
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3988 - accuracy: 0.8265 - val_loss: 0.3855 - val_accuracy: 0.8426
# Epoch 25/150
# 521/563 [==========================>...] - ETA: 0s - loss: 0.3959 - accuracy: 0.8279
# Epoch 25: val_loss did not improve from 0.38375
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3972 - accuracy: 0.8281 - val_loss: 0.4023 - val_accuracy: 0.8395
# Epoch 26/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3966 - accuracy: 0.8296
# Epoch 26: val_loss improved from 0.38375 to 0.38201, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3969 - accuracy: 0.8294 - val_loss: 0.3820 - val_accuracy: 0.8446
# Epoch 27/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3953 - accuracy: 0.8283
# Epoch 27: val_loss did not improve from 0.38201
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3945 - accuracy: 0.8286 - val_loss: 0.3896 - val_accuracy: 0.8439
# Epoch 28/150
# 544/563 [===========================>..] - ETA: 0s - loss: 0.3875 - accuracy: 0.8317
# Epoch 28: val_loss did not improve from 0.38201
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3887 - accuracy: 0.8318 - val_loss: 0.4113 - val_accuracy: 0.8410
# Epoch 29/150
# 550/563 [============================>.] - ETA: 0s - loss: 0.3909 - accuracy: 0.8316
# Epoch 29: val_loss did not improve from 0.38201
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3892 - accuracy: 0.8325 - val_loss: 0.3847 - val_accuracy: 0.8448
# Epoch 30/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3853 - accuracy: 0.8350
# Epoch 30: val_loss did not improve from 0.38201
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3878 - accuracy: 0.8340 - val_loss: 0.4087 - val_accuracy: 0.8446
# Epoch 31/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3911 - accuracy: 0.8328
# Epoch 31: val_loss did not improve from 0.38201
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3909 - accuracy: 0.8328 - val_loss: 0.3913 - val_accuracy: 0.8435
# Epoch 32/150
# 530/563 [===========================>..] - ETA: 0s - loss: 0.3879 - accuracy: 0.8354
# Epoch 32: val_loss improved from 0.38201 to 0.36688, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3882 - accuracy: 0.8349 - val_loss: 0.3669 - val_accuracy: 0.8479
# Epoch 33/150
# 520/563 [==========================>...] - ETA: 0s - loss: 0.3882 - accuracy: 0.8347
# Epoch 33: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3854 - accuracy: 0.8362 - val_loss: 0.3740 - val_accuracy: 0.8490
# Epoch 34/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3892 - accuracy: 0.8370
# Epoch 34: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3890 - accuracy: 0.8370 - val_loss: 0.3973 - val_accuracy: 0.8472
# Epoch 35/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.3840 - accuracy: 0.8298
# Epoch 35: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3834 - accuracy: 0.8307 - val_loss: 0.3805 - val_accuracy: 0.8472
# Epoch 36/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3876 - accuracy: 0.8316
# Epoch 36: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3876 - accuracy: 0.8316 - val_loss: 0.3848 - val_accuracy: 0.8417
# Epoch 37/150
# 521/563 [==========================>...] - ETA: 0s - loss: 0.3829 - accuracy: 0.8374
# Epoch 37: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3823 - accuracy: 0.8380 - val_loss: 0.3836 - val_accuracy: 0.8472
# Epoch 38/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3788 - accuracy: 0.8388
# Epoch 38: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3787 - accuracy: 0.8384 - val_loss: 0.3956 - val_accuracy: 0.8348
# Epoch 39/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3735 - accuracy: 0.8398
# Epoch 39: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3744 - accuracy: 0.8395 - val_loss: 0.3943 - val_accuracy: 0.8319
# Epoch 40/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3756 - accuracy: 0.8392
# Epoch 40: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3759 - accuracy: 0.8393 - val_loss: 0.4024 - val_accuracy: 0.8466
# Epoch 41/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3789 - accuracy: 0.8381
# Epoch 41: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3788 - accuracy: 0.8385 - val_loss: 0.3868 - val_accuracy: 0.8481
# Epoch 42/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.3746 - accuracy: 0.8386
# Epoch 42: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3753 - accuracy: 0.8385 - val_loss: 0.3951 - val_accuracy: 0.8386
# Epoch 43/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.3749 - accuracy: 0.8390
# Epoch 43: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3740 - accuracy: 0.8396 - val_loss: 0.3707 - val_accuracy: 0.8421
# Epoch 44/150
# 521/563 [==========================>...] - ETA: 0s - loss: 0.3804 - accuracy: 0.8376
# Epoch 44: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3823 - accuracy: 0.8365 - val_loss: 0.3855 - val_accuracy: 0.8446
# Epoch 45/150
# 544/563 [===========================>..] - ETA: 0s - loss: 0.3749 - accuracy: 0.8400
# Epoch 45: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3752 - accuracy: 0.8397 - val_loss: 0.3838 - val_accuracy: 0.8486
# Epoch 46/150
# 539/563 [===========================>..] - ETA: 0s - loss: 0.3722 - accuracy: 0.8399
# Epoch 46: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3730 - accuracy: 0.8399 - val_loss: 0.3941 - val_accuracy: 0.8475
# Epoch 47/150
# 537/563 [===========================>..] - ETA: 0s - loss: 0.3741 - accuracy: 0.8437
# Epoch 47: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3750 - accuracy: 0.8436 - val_loss: 0.3786 - val_accuracy: 0.8541
# Epoch 48/150
# 539/563 [===========================>..] - ETA: 0s - loss: 0.3719 - accuracy: 0.8426
# Epoch 48: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3713 - accuracy: 0.8434 - val_loss: 0.3864 - val_accuracy: 0.8479
# Epoch 49/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.3786 - accuracy: 0.8427
# Epoch 49: val_loss did not improve from 0.36688
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3789 - accuracy: 0.8430 - val_loss: 0.3830 - val_accuracy: 0.8521
# Epoch 50/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.3751 - accuracy: 0.8418
# Epoch 50: val_loss improved from 0.36688 to 0.36480, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3746 - accuracy: 0.8419 - val_loss: 0.3648 - val_accuracy: 0.8510
# Epoch 51/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.3695 - accuracy: 0.8438
# Epoch 51: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3695 - accuracy: 0.8433 - val_loss: 0.3738 - val_accuracy: 0.8459
# Epoch 52/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3741 - accuracy: 0.8416
# Epoch 52: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3738 - accuracy: 0.8415 - val_loss: 0.3939 - val_accuracy: 0.8472
# Epoch 53/150
# 554/563 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8394
# Epoch 53: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3710 - accuracy: 0.8399 - val_loss: 0.3726 - val_accuracy: 0.8504
# Epoch 54/150
# 542/563 [===========================>..] - ETA: 0s - loss: 0.3732 - accuracy: 0.8428
# Epoch 54: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3734 - accuracy: 0.8427 - val_loss: 0.3953 - val_accuracy: 0.8484
# Epoch 55/150
# 551/563 [============================>.] - ETA: 0s - loss: 0.3700 - accuracy: 0.8422
# Epoch 55: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3706 - accuracy: 0.8420 - val_loss: 0.3875 - val_accuracy: 0.8570
# Epoch 56/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.3688 - accuracy: 0.8413
# Epoch 56: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3697 - accuracy: 0.8405 - val_loss: 0.3974 - val_accuracy: 0.8570
# Epoch 57/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3721 - accuracy: 0.8381
# Epoch 57: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3723 - accuracy: 0.8376 - val_loss: 0.3902 - val_accuracy: 0.8424
# Epoch 58/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.3669 - accuracy: 0.8447
# Epoch 58: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3665 - accuracy: 0.8443 - val_loss: 0.3864 - val_accuracy: 0.8459
# Epoch 59/150
# 543/563 [===========================>..] - ETA: 0s - loss: 0.3643 - accuracy: 0.8450
# Epoch 59: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3660 - accuracy: 0.8440 - val_loss: 0.4035 - val_accuracy: 0.8477
# Epoch 60/150
# 543/563 [===========================>..] - ETA: 0s - loss: 0.3710 - accuracy: 0.8445
# Epoch 60: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3713 - accuracy: 0.8445 - val_loss: 0.3728 - val_accuracy: 0.8439
# Epoch 61/150
# 541/563 [===========================>..] - ETA: 0s - loss: 0.3627 - accuracy: 0.8464
# Epoch 61: val_loss did not improve from 0.36480
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3613 - accuracy: 0.8465 - val_loss: 0.3654 - val_accuracy: 0.8455
# Epoch 62/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.3643 - accuracy: 0.8451
# Epoch 62: val_loss improved from 0.36480 to 0.36011, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3628 - accuracy: 0.8457 - val_loss: 0.3601 - val_accuracy: 0.8541
# Epoch 63/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.3714 - accuracy: 0.8411
# Epoch 63: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3709 - accuracy: 0.8414 - val_loss: 0.3879 - val_accuracy: 0.8484
# Epoch 64/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3686 - accuracy: 0.8453
# Epoch 64: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3679 - accuracy: 0.8458 - val_loss: 0.3878 - val_accuracy: 0.8470
# Epoch 65/150
# 532/563 [===========================>..] - ETA: 0s - loss: 0.3650 - accuracy: 0.8438
# Epoch 65: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3658 - accuracy: 0.8435 - val_loss: 0.3795 - val_accuracy: 0.8472
# Epoch 66/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3656 - accuracy: 0.8469
# Epoch 66: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3668 - accuracy: 0.8469 - val_loss: 0.3979 - val_accuracy: 0.8435
# Epoch 67/150
# 539/563 [===========================>..] - ETA: 0s - loss: 0.3661 - accuracy: 0.8465
# Epoch 67: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3669 - accuracy: 0.8454 - val_loss: 0.3952 - val_accuracy: 0.8426
# Epoch 68/150
# 536/563 [===========================>..] - ETA: 0s - loss: 0.3627 - accuracy: 0.8478
# Epoch 68: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3640 - accuracy: 0.8473 - val_loss: 0.3949 - val_accuracy: 0.8499
# Epoch 69/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3623 - accuracy: 0.8471
# Epoch 69: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3623 - accuracy: 0.8475 - val_loss: 0.3783 - val_accuracy: 0.8508
# Epoch 70/150
# 544/563 [===========================>..] - ETA: 0s - loss: 0.3636 - accuracy: 0.8461
# Epoch 70: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3637 - accuracy: 0.8464 - val_loss: 0.3844 - val_accuracy: 0.8464
# Epoch 71/150
# 542/563 [===========================>..] - ETA: 0s - loss: 0.3650 - accuracy: 0.8505
# Epoch 71: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3645 - accuracy: 0.8504 - val_loss: 0.3772 - val_accuracy: 0.8492
# Epoch 72/150
# 543/563 [===========================>..] - ETA: 0s - loss: 0.3633 - accuracy: 0.8482
# Epoch 72: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3627 - accuracy: 0.8481 - val_loss: 0.3825 - val_accuracy: 0.8470
# Epoch 73/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.3651 - accuracy: 0.8467
# Epoch 73: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3649 - accuracy: 0.8472 - val_loss: 0.3710 - val_accuracy: 0.8555
# Epoch 74/150
# 541/563 [===========================>..] - ETA: 0s - loss: 0.3585 - accuracy: 0.8494
# Epoch 74: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3611 - accuracy: 0.8493 - val_loss: 0.3885 - val_accuracy: 0.8579
# Epoch 75/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3610 - accuracy: 0.8498
# Epoch 75: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3612 - accuracy: 0.8496 - val_loss: 0.3757 - val_accuracy: 0.8528
# Epoch 76/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3620 - accuracy: 0.8480
# Epoch 76: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8476 - val_loss: 0.3618 - val_accuracy: 0.8504
# Epoch 77/150
# 541/563 [===========================>..] - ETA: 0s - loss: 0.3583 - accuracy: 0.8468
# Epoch 77: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3589 - accuracy: 0.8470 - val_loss: 0.4014 - val_accuracy: 0.8548
# Epoch 78/150
# 537/563 [===========================>..] - ETA: 0s - loss: 0.3623 - accuracy: 0.8476
# Epoch 78: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8480 - val_loss: 0.3731 - val_accuracy: 0.8504
# Epoch 79/150
# 529/563 [===========================>..] - ETA: 0s - loss: 0.3702 - accuracy: 0.8459
# Epoch 79: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3696 - accuracy: 0.8467 - val_loss: 0.3714 - val_accuracy: 0.8548
# Epoch 80/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.3602 - accuracy: 0.8496
# Epoch 80: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3601 - accuracy: 0.8495 - val_loss: 0.3649 - val_accuracy: 0.8532
# Epoch 81/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.3637 - accuracy: 0.8481
# Epoch 81: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3624 - accuracy: 0.8485 - val_loss: 0.3747 - val_accuracy: 0.8541
# Epoch 82/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.3580 - accuracy: 0.8497
# Epoch 82: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3582 - accuracy: 0.8497 - val_loss: 0.3714 - val_accuracy: 0.8537
# Epoch 83/150
# 542/563 [===========================>..] - ETA: 0s - loss: 0.3619 - accuracy: 0.8463
# Epoch 83: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3612 - accuracy: 0.8470 - val_loss: 0.3651 - val_accuracy: 0.8490
# Epoch 84/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3635 - accuracy: 0.8465
# Epoch 84: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3633 - accuracy: 0.8467 - val_loss: 0.3806 - val_accuracy: 0.8530
# Epoch 85/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3649 - accuracy: 0.8490
# Epoch 85: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3651 - accuracy: 0.8484 - val_loss: 0.3670 - val_accuracy: 0.8481
# Epoch 86/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.3603 - accuracy: 0.8525
# Epoch 86: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3606 - accuracy: 0.8525 - val_loss: 0.3725 - val_accuracy: 0.8526
# Epoch 87/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.8496
# Epoch 87: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3606 - accuracy: 0.8490 - val_loss: 0.3736 - val_accuracy: 0.8481
# Epoch 88/150
# 544/563 [===========================>..] - ETA: 0s - loss: 0.3591 - accuracy: 0.8523
# Epoch 88: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3593 - accuracy: 0.8518 - val_loss: 0.3721 - val_accuracy: 0.8468
# Epoch 89/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3526 - accuracy: 0.8509
# Epoch 89: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3538 - accuracy: 0.8507 - val_loss: 0.3786 - val_accuracy: 0.8524
# Epoch 90/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.3605 - accuracy: 0.8457
# Epoch 90: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3609 - accuracy: 0.8456 - val_loss: 0.3805 - val_accuracy: 0.8519
# Epoch 91/150
# 554/563 [============================>.] - ETA: 0s - loss: 0.3588 - accuracy: 0.8486
# Epoch 91: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3585 - accuracy: 0.8487 - val_loss: 0.3943 - val_accuracy: 0.8479
# Epoch 92/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.3614 - accuracy: 0.8491
# Epoch 92: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3604 - accuracy: 0.8501 - val_loss: 0.3694 - val_accuracy: 0.8512
# Epoch 93/150
# 540/563 [===========================>..] - ETA: 0s - loss: 0.3576 - accuracy: 0.8490
# Epoch 93: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3587 - accuracy: 0.8488 - val_loss: 0.3842 - val_accuracy: 0.8475
# Epoch 94/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8496
# Epoch 94: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3576 - accuracy: 0.8503 - val_loss: 0.3778 - val_accuracy: 0.8488
# Epoch 95/150
# 542/563 [===========================>..] - ETA: 0s - loss: 0.3567 - accuracy: 0.8511
# Epoch 95: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3586 - accuracy: 0.8504 - val_loss: 0.3851 - val_accuracy: 0.8526
# Epoch 96/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3568 - accuracy: 0.8517
# Epoch 96: val_loss did not improve from 0.36011
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3580 - accuracy: 0.8516 - val_loss: 0.3755 - val_accuracy: 0.8524
# Epoch 97/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.3531 - accuracy: 0.8505
# Epoch 97: val_loss improved from 0.36011 to 0.35605, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3528 - accuracy: 0.8505 - val_loss: 0.3560 - val_accuracy: 0.8539
# Epoch 98/150
# 539/563 [===========================>..] - ETA: 0s - loss: 0.3591 - accuracy: 0.8512
# Epoch 98: val_loss did not improve from 0.35605
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3605 - accuracy: 0.8503 - val_loss: 0.3848 - val_accuracy: 0.8470
# Epoch 99/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3556 - accuracy: 0.8516
# Epoch 99: val_loss improved from 0.35605 to 0.34759, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3558 - accuracy: 0.8516 - val_loss: 0.3476 - val_accuracy: 0.8583
# Epoch 100/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3596 - accuracy: 0.8490
# Epoch 100: val_loss did not improve from 0.34759
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3592 - accuracy: 0.8486 - val_loss: 0.3682 - val_accuracy: 0.8563
# Epoch 101/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.8484
# Epoch 101: val_loss improved from 0.34759 to 0.33821, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3578 - accuracy: 0.8493 - val_loss: 0.3382 - val_accuracy: 0.8570
# Epoch 102/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.3611 - accuracy: 0.8509
# Epoch 102: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3614 - accuracy: 0.8502 - val_loss: 0.3881 - val_accuracy: 0.8452
# Epoch 103/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8514
# Epoch 103: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3588 - accuracy: 0.8511 - val_loss: 0.3705 - val_accuracy: 0.8544
# Epoch 104/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3617 - accuracy: 0.8459
# Epoch 104: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8460 - val_loss: 0.3621 - val_accuracy: 0.8512
# Epoch 105/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3589 - accuracy: 0.8465
# Epoch 105: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3587 - accuracy: 0.8464 - val_loss: 0.3838 - val_accuracy: 0.8541
# Epoch 106/150
# 536/563 [===========================>..] - ETA: 0s - loss: 0.3591 - accuracy: 0.8518
# Epoch 106: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3589 - accuracy: 0.8525 - val_loss: 0.3579 - val_accuracy: 0.8535
# Epoch 107/150
# 550/563 [============================>.] - ETA: 0s - loss: 0.3599 - accuracy: 0.8499
# Epoch 107: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3595 - accuracy: 0.8497 - val_loss: 0.3590 - val_accuracy: 0.8563
# Epoch 108/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3531 - accuracy: 0.8520
# Epoch 108: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3528 - accuracy: 0.8521 - val_loss: 0.3767 - val_accuracy: 0.8563
# Epoch 109/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3555 - accuracy: 0.8491
# Epoch 109: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3555 - accuracy: 0.8490 - val_loss: 0.3767 - val_accuracy: 0.8535
# Epoch 110/150
# 529/563 [===========================>..] - ETA: 0s - loss: 0.3554 - accuracy: 0.8510
# Epoch 110: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3568 - accuracy: 0.8505 - val_loss: 0.3698 - val_accuracy: 0.8570
# Epoch 111/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3582 - accuracy: 0.8495
# Epoch 111: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3580 - accuracy: 0.8495 - val_loss: 0.3660 - val_accuracy: 0.8592
# Epoch 112/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8551
# Epoch 112: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3516 - accuracy: 0.8548 - val_loss: 0.3745 - val_accuracy: 0.8479
# Epoch 113/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3595 - accuracy: 0.8487
# Epoch 113: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3583 - accuracy: 0.8498 - val_loss: 0.3628 - val_accuracy: 0.8510
# Epoch 114/150
# 537/563 [===========================>..] - ETA: 0s - loss: 0.3550 - accuracy: 0.8510
# Epoch 114: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3538 - accuracy: 0.8518 - val_loss: 0.3601 - val_accuracy: 0.8517
# Epoch 115/150
# 543/563 [===========================>..] - ETA: 0s - loss: 0.3529 - accuracy: 0.8467
# Epoch 115: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3524 - accuracy: 0.8469 - val_loss: 0.3510 - val_accuracy: 0.8490
# Epoch 116/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3552 - accuracy: 0.8504
# Epoch 116: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3552 - accuracy: 0.8504 - val_loss: 0.3895 - val_accuracy: 0.8455
# Epoch 117/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3618 - accuracy: 0.8479
# Epoch 117: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3618 - accuracy: 0.8477 - val_loss: 0.3788 - val_accuracy: 0.8521
# Epoch 118/150
# 529/563 [===========================>..] - ETA: 0s - loss: 0.3555 - accuracy: 0.8523
# Epoch 118: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3564 - accuracy: 0.8521 - val_loss: 0.3863 - val_accuracy: 0.8524
# Epoch 119/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3536 - accuracy: 0.8518
# Epoch 119: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3527 - accuracy: 0.8527 - val_loss: 0.3690 - val_accuracy: 0.8504
# Epoch 120/150
# 551/563 [============================>.] - ETA: 0s - loss: 0.3571 - accuracy: 0.8511
# Epoch 120: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3585 - accuracy: 0.8504 - val_loss: 0.4148 - val_accuracy: 0.8510
# Epoch 121/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3506 - accuracy: 0.8526
# Epoch 121: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3507 - accuracy: 0.8524 - val_loss: 0.3494 - val_accuracy: 0.8532
# Epoch 122/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8501
# Epoch 122: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3495 - accuracy: 0.8502 - val_loss: 0.3474 - val_accuracy: 0.8592
# Epoch 123/150
# 548/563 [============================>.] - ETA: 0s - loss: 0.3553 - accuracy: 0.8510
# Epoch 123: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3540 - accuracy: 0.8514 - val_loss: 0.3554 - val_accuracy: 0.8577
# Epoch 124/150
# 554/563 [============================>.] - ETA: 0s - loss: 0.3573 - accuracy: 0.8515
# Epoch 124: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3571 - accuracy: 0.8516 - val_loss: 0.3579 - val_accuracy: 0.8566
# Epoch 125/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3574 - accuracy: 0.8517
# Epoch 125: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3579 - accuracy: 0.8517 - val_loss: 0.3565 - val_accuracy: 0.8532
# Epoch 126/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3531 - accuracy: 0.8528
# Epoch 126: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3531 - accuracy: 0.8528 - val_loss: 0.3688 - val_accuracy: 0.8517
# Epoch 127/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.3516 - accuracy: 0.8557
# Epoch 127: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3520 - accuracy: 0.8556 - val_loss: 0.3582 - val_accuracy: 0.8481
# Epoch 128/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.8521
# Epoch 128: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3480 - accuracy: 0.8522 - val_loss: 0.3732 - val_accuracy: 0.8510
# Epoch 129/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.3565 - accuracy: 0.8526
# Epoch 129: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3563 - accuracy: 0.8526 - val_loss: 0.3816 - val_accuracy: 0.8575
# Epoch 130/150
# 537/563 [===========================>..] - ETA: 0s - loss: 0.3548 - accuracy: 0.8464
# Epoch 130: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3575 - accuracy: 0.8459 - val_loss: 0.4057 - val_accuracy: 0.8479
# Epoch 131/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.3515 - accuracy: 0.8509
# Epoch 131: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3508 - accuracy: 0.8515 - val_loss: 0.3666 - val_accuracy: 0.8606
# Epoch 132/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3511 - accuracy: 0.8521
# Epoch 132: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3516 - accuracy: 0.8525 - val_loss: 0.3639 - val_accuracy: 0.8575
# Epoch 133/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3526 - accuracy: 0.8525
# Epoch 133: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 2ms/step - loss: 0.3534 - accuracy: 0.8524 - val_loss: 0.3563 - val_accuracy: 0.8528
# Epoch 134/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3559 - accuracy: 0.8519
# Epoch 134: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3567 - accuracy: 0.8514 - val_loss: 0.3769 - val_accuracy: 0.8548
# Epoch 135/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.3540 - accuracy: 0.8516
# Epoch 135: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3523 - accuracy: 0.8526 - val_loss: 0.3620 - val_accuracy: 0.8555
# Epoch 136/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.3529 - accuracy: 0.8507
# Epoch 136: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3526 - accuracy: 0.8507 - val_loss: 0.3784 - val_accuracy: 0.8470
# Epoch 137/150
# 535/563 [===========================>..] - ETA: 0s - loss: 0.3536 - accuracy: 0.8536
# Epoch 137: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3543 - accuracy: 0.8533 - val_loss: 0.3868 - val_accuracy: 0.8406
# Epoch 138/150
# 541/563 [===========================>..] - ETA: 0s - loss: 0.3491 - accuracy: 0.8555
# Epoch 138: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3500 - accuracy: 0.8548 - val_loss: 0.3762 - val_accuracy: 0.8512
# Epoch 139/150
# 525/563 [==========================>...] - ETA: 0s - loss: 0.3478 - accuracy: 0.8526
# Epoch 139: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3499 - accuracy: 0.8515 - val_loss: 0.3844 - val_accuracy: 0.8532
# Epoch 140/150
# 528/563 [===========================>..] - ETA: 0s - loss: 0.3521 - accuracy: 0.8546
# Epoch 140: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3515 - accuracy: 0.8544 - val_loss: 0.3560 - val_accuracy: 0.8537
# Epoch 141/150
# 550/563 [============================>.] - ETA: 0s - loss: 0.3560 - accuracy: 0.8564
# Epoch 141: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3573 - accuracy: 0.8561 - val_loss: 0.3657 - val_accuracy: 0.8555
# Epoch 142/150
# 538/563 [===========================>..] - ETA: 0s - loss: 0.3520 - accuracy: 0.8530
# Epoch 142: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3542 - accuracy: 0.8532 - val_loss: 0.3776 - val_accuracy: 0.8521
# Epoch 143/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8511
# Epoch 143: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3500 - accuracy: 0.8511 - val_loss: 0.3728 - val_accuracy: 0.8499
# Epoch 144/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3509 - accuracy: 0.8539
# Epoch 144: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3513 - accuracy: 0.8537 - val_loss: 0.3718 - val_accuracy: 0.8515
# Epoch 145/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8544
# Epoch 145: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3513 - accuracy: 0.8549 - val_loss: 0.3669 - val_accuracy: 0.8515
# Epoch 146/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3528 - accuracy: 0.8535
# Epoch 146: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3523 - accuracy: 0.8537 - val_loss: 0.3518 - val_accuracy: 0.8519
# Epoch 147/150
# 537/563 [===========================>..] - ETA: 0s - loss: 0.3570 - accuracy: 0.8503
# Epoch 147: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3567 - accuracy: 0.8504 - val_loss: 0.3745 - val_accuracy: 0.8535
# Epoch 148/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.3531 - accuracy: 0.8548
# Epoch 148: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3540 - accuracy: 0.8542 - val_loss: 0.3721 - val_accuracy: 0.8601
# Epoch 149/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.3487 - accuracy: 0.8563
# Epoch 149: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3484 - accuracy: 0.8566 - val_loss: 0.3559 - val_accuracy: 0.8506
# Epoch 150/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3529 - accuracy: 0.8531
# Epoch 150: val_loss did not improve from 0.33821
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3534 - accuracy: 0.8529 - val_loss: 0.3748 - val_accuracy: 0.8555
# Training completed in time:  0:02:04.117726

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.855461835861206
