# %% [markdown]
# # Voice Activity

# %%
import os
import librosa
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
from keras.models import Sequential
from keras.layers import Flatten, Dropout, Activation, Conv1D, MaxPooling1D, Dense
from sklearn import preprocessing
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score, recall_score, f1_score
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten
from tensorflow.keras.optimizers import Adam
from sklearn import metrics

# %%
# Seed value
# Apparently you may use different seed values at each stage
seed_value= 0

# 1. Set the `PYTHONHASHSEED` environment variable at a fixed value
import os
os.environ['PYTHONHASHSEED']=str(seed_value)

# 2. Set the `python` built-in pseudo-random generator at a fixed value
import random
random.seed(seed_value)

# 3. Set the `numpy` pseudo-random generator at a fixed value
import numpy as np
np.random.seed(seed_value)

# 4. Set the `tensorflow` pseudo-random generator at a fixed value
import tensorflow as tf
tf.random.set_seed(seed_value)
# for later versions: 
# tf.compat.v1.set_random_seed(seed_value)

# %% [markdown]
# ### Relative Path

# %%
cur_path = os.getcwd()

# %% [markdown]
# # 1. Read Sample File

# %%
def features_extractor(file_name):
    audio, sample_rate = librosa.load(file_name, res_type='kaiser_fast') 
    mfccs_features = librosa.feature.mfcc(y=audio, sr=sample_rate, n_mfcc=40)
    mfccs_scaled_features = np.mean(mfccs_features.T,axis=0)
    
    return mfccs_scaled_features

# %%
recordNames = os.listdir("./ses/")
SampleNumbers = {}
recordNames.remove('.DS_Store')

# %%
recordDatasets = {}
numberOfSamples = []
for recordName in recordNames:
    path_0 = os.path.relpath(f'./ses/{recordName}/samples_0', cur_path)
    path_1 = os.path.relpath(f'./ses/{recordName}/samples_1', cur_path)
    AudioFiles_0 = [f for f in os.listdir(path_0) if os.path.isfile(os.path.join(path_0, f))]
    AudioFiles_1 = [f for f in os.listdir(path_1) if os.path.isfile(os.path.join(path_1, f))]
    SampleNumbers[recordName] = {
        "Child" : len(AudioFiles_1),
        "NonChild" : len(AudioFiles_0)
    }
    features = []
    labels = []
    n = min(len(AudioFiles_0), len(AudioFiles_1))
    selectedSamples_0 = random.sample(AudioFiles_0, n)
    selectedSamples_1 = random.sample(AudioFiles_1, n)
    for i in range(n):
        features.append(features_extractor(path_0 + "/" + selectedSamples_0[i]))
        labels.append(0)
        features.append(features_extractor(path_1 + "/" + selectedSamples_1[i]))
        labels.append(1)
    print(f"Dataset: {recordName} Number of Samples: {len(labels)}")
    recordDatasets[f"{recordName}"] = {
        "features" : features,
        "labels" : labels
    }
    numberOfSamples.append(len(labels))
# Out:
# Dataset: ENG Number of Samples: 0
# Dataset: 4CH072I Number of Samples: 722
# Dataset: 4CH071I Number of Samples: 218
# Dataset: 4CH069I Number of Samples: 1106
# Dataset: 4CH067I Number of Samples: 858
# Dataset: MAAP3 Number of Samples: 2184
# Dataset: MAAP5 Number of Samples: 2222
# Dataset: MAAP2 Number of Samples: 1964
# Dataset: 4CH065I Number of Samples: 976
# Dataset: 4CH066I Number of Samples: 4544
# Dataset: 4CH068I Number of Samples: 3696
# Dataset: MAAP7 Number of Samples: 2566
# Dataset: MAAP6 Number of Samples: 1462

# %%
X, y = [], []
for recordName in recordNames:
    X.extend(recordDatasets[recordName]['features'])
    y.extend(recordDatasets[recordName]['labels'])
X = np.array(X)
y = np.array(y)

# %%
### Train Test Split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
model=Sequential()
###first layer
model.add(Dense(100,input_shape=(40,)))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###second layer
model.add(Dense(200))
model.add(Activation('relu'))
model.add(Dropout(0.5))
###third layer
model.add(Dense(100))
model.add(Activation('relu'))
model.add(Dropout(0.5))

###final layer
model.add(Dense(1))
model.add(Activation('sigmoid'))

# %%
model.compile(loss='binary_crossentropy',metrics=['accuracy'],optimizer='adam')

# %%
## Trianing my model
from tensorflow.keras.callbacks import ModelCheckpoint
from datetime import datetime 

num_epochs = 150
num_batch_size = 32

checkpointer = ModelCheckpoint(filepath='saved_models/audio_classification.hdf5', 
                               verbose=1, save_best_only=True)
start = datetime.now()

model.fit(X_train, y_train, batch_size=num_batch_size, epochs=num_epochs, validation_data=(X_test, y_test), callbacks=[checkpointer], verbose=1)


duration = datetime.now() - start
print("Training completed in time: ", duration)
# Out:
# Epoch 1/150
# 541/563 [===========================>..] - ETA: 0s - loss: 3.3281 - accuracy: 0.5251
# Epoch 1: val_loss improved from inf to 0.69417, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 3.2284 - accuracy: 0.5259 - val_loss: 0.6942 - val_accuracy: 0.5018
# Epoch 2/150
# 543/563 [===========================>..] - ETA: 0s - loss: 0.7183 - accuracy: 0.5545
# Epoch 2: val_loss improved from 0.69417 to 0.67444, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.7177 - accuracy: 0.5547 - val_loss: 0.6744 - val_accuracy: 0.6521
# Epoch 3/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.6717 - accuracy: 0.5967
# Epoch 3: val_loss improved from 0.67444 to 0.63539, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 2ms/step - loss: 0.6715 - accuracy: 0.5970 - val_loss: 0.6354 - val_accuracy: 0.7305
# Epoch 4/150
# 541/563 [===========================>..] - ETA: 0s - loss: 0.6129 - accuracy: 0.6669
# Epoch 4: val_loss improved from 0.63539 to 0.52753, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.6102 - accuracy: 0.6686 - val_loss: 0.5275 - val_accuracy: 0.7640
# Epoch 5/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.5603 - accuracy: 0.7179
# Epoch 5: val_loss improved from 0.52753 to 0.48468, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.5602 - accuracy: 0.7183 - val_loss: 0.4847 - val_accuracy: 0.7933
# Epoch 6/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.5193 - accuracy: 0.7519
# Epoch 6: val_loss improved from 0.48468 to 0.45556, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.5195 - accuracy: 0.7515 - val_loss: 0.4556 - val_accuracy: 0.8020
# Epoch 7/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.4942 - accuracy: 0.7659
# Epoch 7: val_loss improved from 0.45556 to 0.44687, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4948 - accuracy: 0.7655 - val_loss: 0.4469 - val_accuracy: 0.8155
# Epoch 8/150
# 530/563 [===========================>..] - ETA: 0s - loss: 0.4784 - accuracy: 0.7802
# Epoch 8: val_loss improved from 0.44687 to 0.43479, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4789 - accuracy: 0.7804 - val_loss: 0.4348 - val_accuracy: 0.8259
# Epoch 9/150
# 526/563 [===========================>..] - ETA: 0s - loss: 0.4630 - accuracy: 0.7843
# Epoch 9: val_loss improved from 0.43479 to 0.39327, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4615 - accuracy: 0.7855 - val_loss: 0.3933 - val_accuracy: 0.8286
# Epoch 10/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.4573 - accuracy: 0.7928
# Epoch 10: val_loss improved from 0.39327 to 0.39228, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4570 - accuracy: 0.7930 - val_loss: 0.3923 - val_accuracy: 0.8319
# Epoch 11/150
# 519/563 [==========================>...] - ETA: 0s - loss: 0.4443 - accuracy: 0.7997
# Epoch 11: val_loss did not improve from 0.39228
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4453 - accuracy: 0.7996 - val_loss: 0.4203 - val_accuracy: 0.8330
# Epoch 12/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.4392 - accuracy: 0.8048
# Epoch 12: val_loss improved from 0.39228 to 0.39043, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4385 - accuracy: 0.8045 - val_loss: 0.3904 - val_accuracy: 0.8339
# Epoch 13/150
# 528/563 [===========================>..] - ETA: 0s - loss: 0.4354 - accuracy: 0.8072
# Epoch 13: val_loss did not improve from 0.39043
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4371 - accuracy: 0.8070 - val_loss: 0.4000 - val_accuracy: 0.8395
# Epoch 14/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.4279 - accuracy: 0.8127
# Epoch 14: val_loss did not improve from 0.39043
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4279 - accuracy: 0.8126 - val_loss: 0.4021 - val_accuracy: 0.8368
# Epoch 15/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.4261 - accuracy: 0.8127
# Epoch 15: val_loss improved from 0.39043 to 0.37767, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4255 - accuracy: 0.8134 - val_loss: 0.3777 - val_accuracy: 0.8426
# Epoch 16/150
# 555/563 [============================>.] - ETA: 0s - loss: 0.4246 - accuracy: 0.8177
# Epoch 16: val_loss did not improve from 0.37767
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4239 - accuracy: 0.8179 - val_loss: 0.3802 - val_accuracy: 0.8446
# Epoch 17/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.4124 - accuracy: 0.8213
# Epoch 17: val_loss did not improve from 0.37767
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4127 - accuracy: 0.8211 - val_loss: 0.3890 - val_accuracy: 0.8421
# Epoch 18/150
# 528/563 [===========================>..] - ETA: 0s - loss: 0.4046 - accuracy: 0.8242
# Epoch 18: val_loss did not improve from 0.37767
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4061 - accuracy: 0.8227 - val_loss: 0.4032 - val_accuracy: 0.8479
# Epoch 19/150
# 523/563 [==========================>...] - ETA: 0s - loss: 0.4067 - accuracy: 0.8252
# Epoch 19: val_loss improved from 0.37767 to 0.37458, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4058 - accuracy: 0.8254 - val_loss: 0.3746 - val_accuracy: 0.8504
# Epoch 20/150
# 546/563 [============================>.] - ETA: 0s - loss: 0.4024 - accuracy: 0.8277
# Epoch 20: val_loss did not improve from 0.37458
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4027 - accuracy: 0.8275 - val_loss: 0.3872 - val_accuracy: 0.8439
# Epoch 21/150
# 547/563 [============================>.] - ETA: 0s - loss: 0.4023 - accuracy: 0.8233
# Epoch 21: val_loss did not improve from 0.37458
# 563/563 [==============================] - 1s 1ms/step - loss: 0.4025 - accuracy: 0.8237 - val_loss: 0.3766 - val_accuracy: 0.8528
# Epoch 22/150
# 530/563 [===========================>..] - ETA: 0s - loss: 0.3995 - accuracy: 0.8292
# Epoch 22: val_loss did not improve from 0.37458
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3980 - accuracy: 0.8292 - val_loss: 0.3781 - val_accuracy: 0.8492
# Epoch 23/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3996 - accuracy: 0.8283
# Epoch 23: val_loss did not improve from 0.37458
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3995 - accuracy: 0.8284 - val_loss: 0.3979 - val_accuracy: 0.8572
# Epoch 24/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3922 - accuracy: 0.8315
# Epoch 24: val_loss improved from 0.37458 to 0.37321, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3915 - accuracy: 0.8317 - val_loss: 0.3732 - val_accuracy: 0.8546
# Epoch 25/150
# 536/563 [===========================>..] - ETA: 0s - loss: 0.3901 - accuracy: 0.8320
# Epoch 25: val_loss improved from 0.37321 to 0.37061, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3903 - accuracy: 0.8320 - val_loss: 0.3706 - val_accuracy: 0.8577
# Epoch 26/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3918 - accuracy: 0.8309
# Epoch 26: val_loss did not improve from 0.37061
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3918 - accuracy: 0.8309 - val_loss: 0.3772 - val_accuracy: 0.8575
# Epoch 27/150
# 531/563 [===========================>..] - ETA: 0s - loss: 0.3872 - accuracy: 0.8360
# Epoch 27: val_loss did not improve from 0.37061
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3888 - accuracy: 0.8348 - val_loss: 0.3919 - val_accuracy: 0.8563
# Epoch 28/150
# 550/563 [============================>.] - ETA: 0s - loss: 0.3899 - accuracy: 0.8334
# Epoch 28: val_loss did not improve from 0.37061
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3900 - accuracy: 0.8334 - val_loss: 0.3709 - val_accuracy: 0.8552
# Epoch 29/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3892 - accuracy: 0.8351
# Epoch 29: val_loss did not improve from 0.37061
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3894 - accuracy: 0.8349 - val_loss: 0.3900 - val_accuracy: 0.8535
# Epoch 30/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3873 - accuracy: 0.8342
# Epoch 30: val_loss did not improve from 0.37061
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3873 - accuracy: 0.8342 - val_loss: 0.3791 - val_accuracy: 0.8559
# Epoch 31/150
# 521/563 [==========================>...] - ETA: 0s - loss: 0.3851 - accuracy: 0.8354
# Epoch 31: val_loss did not improve from 0.37061
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3848 - accuracy: 0.8354 - val_loss: 0.3708 - val_accuracy: 0.8537
# Epoch 32/150
# 531/563 [===========================>..] - ETA: 0s - loss: 0.3846 - accuracy: 0.8347
# Epoch 32: val_loss improved from 0.37061 to 0.36882, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3847 - accuracy: 0.8349 - val_loss: 0.3688 - val_accuracy: 0.8608
# Epoch 33/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3856 - accuracy: 0.8379
# Epoch 33: val_loss did not improve from 0.36882
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3853 - accuracy: 0.8381 - val_loss: 0.3766 - val_accuracy: 0.8586
# Epoch 34/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.3895 - accuracy: 0.8343
# Epoch 34: val_loss improved from 0.36882 to 0.35817, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3878 - accuracy: 0.8346 - val_loss: 0.3582 - val_accuracy: 0.8550
# Epoch 35/150
# 524/563 [==========================>...] - ETA: 0s - loss: 0.3850 - accuracy: 0.8373
# Epoch 35: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3861 - accuracy: 0.8366 - val_loss: 0.3944 - val_accuracy: 0.8581
# Epoch 36/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3817 - accuracy: 0.8385
# Epoch 36: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3820 - accuracy: 0.8383 - val_loss: 0.3707 - val_accuracy: 0.8601
# Epoch 37/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3854 - accuracy: 0.8347
# Epoch 37: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3856 - accuracy: 0.8345 - val_loss: 0.3659 - val_accuracy: 0.8563
# Epoch 38/150
# 525/563 [==========================>...] - ETA: 0s - loss: 0.3777 - accuracy: 0.8392
# Epoch 38: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3772 - accuracy: 0.8397 - val_loss: 0.3758 - val_accuracy: 0.8506
# Epoch 39/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3762 - accuracy: 0.8396
# Epoch 39: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3758 - accuracy: 0.8397 - val_loss: 0.3839 - val_accuracy: 0.8528
# Epoch 40/150
# 550/563 [============================>.] - ETA: 0s - loss: 0.3771 - accuracy: 0.8399
# Epoch 40: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3775 - accuracy: 0.8398 - val_loss: 0.3670 - val_accuracy: 0.8581
# Epoch 41/150
# 529/563 [===========================>..] - ETA: 0s - loss: 0.3777 - accuracy: 0.8362
# Epoch 41: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3770 - accuracy: 0.8367 - val_loss: 0.3825 - val_accuracy: 0.8595
# Epoch 42/150
# 532/563 [===========================>..] - ETA: 0s - loss: 0.3780 - accuracy: 0.8400
# Epoch 42: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3792 - accuracy: 0.8405 - val_loss: 0.3928 - val_accuracy: 0.8544
# Epoch 43/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3731 - accuracy: 0.8399
# Epoch 43: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3729 - accuracy: 0.8399 - val_loss: 0.3596 - val_accuracy: 0.8517
# Epoch 44/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3792 - accuracy: 0.8400
# Epoch 44: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3793 - accuracy: 0.8398 - val_loss: 0.3627 - val_accuracy: 0.8566
# Epoch 45/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3780 - accuracy: 0.8411
# Epoch 45: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3781 - accuracy: 0.8408 - val_loss: 0.3883 - val_accuracy: 0.8486
# Epoch 46/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3775 - accuracy: 0.8411
# Epoch 46: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3774 - accuracy: 0.8412 - val_loss: 0.3643 - val_accuracy: 0.8608
# Epoch 47/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3665 - accuracy: 0.8440
# Epoch 47: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3681 - accuracy: 0.8436 - val_loss: 0.3973 - val_accuracy: 0.8572
# Epoch 48/150
# 523/563 [==========================>...] - ETA: 0s - loss: 0.3683 - accuracy: 0.8432
# Epoch 48: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3684 - accuracy: 0.8433 - val_loss: 0.3605 - val_accuracy: 0.8597
# Epoch 49/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3753 - accuracy: 0.8422
# Epoch 49: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3753 - accuracy: 0.8422 - val_loss: 0.3609 - val_accuracy: 0.8583
# Epoch 50/150
# 523/563 [==========================>...] - ETA: 0s - loss: 0.3716 - accuracy: 0.8427
# Epoch 50: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3750 - accuracy: 0.8413 - val_loss: 0.3973 - val_accuracy: 0.8597
# Epoch 51/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.3687 - accuracy: 0.8465
# Epoch 51: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3697 - accuracy: 0.8460 - val_loss: 0.3873 - val_accuracy: 0.8563
# Epoch 52/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3670 - accuracy: 0.8436
# Epoch 52: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3670 - accuracy: 0.8437 - val_loss: 0.3587 - val_accuracy: 0.8626
# Epoch 53/150
# 526/563 [===========================>..] - ETA: 0s - loss: 0.3727 - accuracy: 0.8420
# Epoch 53: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3732 - accuracy: 0.8418 - val_loss: 0.3763 - val_accuracy: 0.8648
# Epoch 54/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.3719 - accuracy: 0.8405
# Epoch 54: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3725 - accuracy: 0.8401 - val_loss: 0.3786 - val_accuracy: 0.8561
# Epoch 55/150
# 524/563 [==========================>...] - ETA: 0s - loss: 0.3714 - accuracy: 0.8403
# Epoch 55: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3720 - accuracy: 0.8408 - val_loss: 0.3728 - val_accuracy: 0.8570
# Epoch 56/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3682 - accuracy: 0.8448
# Epoch 56: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3694 - accuracy: 0.8445 - val_loss: 0.3865 - val_accuracy: 0.8592
# Epoch 57/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3670 - accuracy: 0.8443
# Epoch 57: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3668 - accuracy: 0.8445 - val_loss: 0.3742 - val_accuracy: 0.8601
# Epoch 58/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.3682 - accuracy: 0.8444
# Epoch 58: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3685 - accuracy: 0.8442 - val_loss: 0.3841 - val_accuracy: 0.8555
# Epoch 59/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3691 - accuracy: 0.8423
# Epoch 59: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3691 - accuracy: 0.8423 - val_loss: 0.3610 - val_accuracy: 0.8648
# Epoch 60/150
# 551/563 [============================>.] - ETA: 0s - loss: 0.3684 - accuracy: 0.8382
# Epoch 60: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3690 - accuracy: 0.8386 - val_loss: 0.3706 - val_accuracy: 0.8610
# Epoch 61/150
# 523/563 [==========================>...] - ETA: 0s - loss: 0.3724 - accuracy: 0.8409
# Epoch 61: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3721 - accuracy: 0.8407 - val_loss: 0.3666 - val_accuracy: 0.8612
# Epoch 62/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3663 - accuracy: 0.8450
# Epoch 62: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3656 - accuracy: 0.8452 - val_loss: 0.3612 - val_accuracy: 0.8566
# Epoch 63/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.3693 - accuracy: 0.8436
# Epoch 63: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3692 - accuracy: 0.8433 - val_loss: 0.3609 - val_accuracy: 0.8635
# Epoch 64/150
# 526/563 [===========================>..] - ETA: 0s - loss: 0.3658 - accuracy: 0.8447
# Epoch 64: val_loss did not improve from 0.35817
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3668 - accuracy: 0.8433 - val_loss: 0.3794 - val_accuracy: 0.8606
# Epoch 65/150
# 528/563 [===========================>..] - ETA: 0s - loss: 0.3596 - accuracy: 0.8467
# Epoch 65: val_loss improved from 0.35817 to 0.34110, saving model to saved_models/audio_classification.hdf5
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3593 - accuracy: 0.8471 - val_loss: 0.3411 - val_accuracy: 0.8639
# Epoch 66/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3625 - accuracy: 0.8436
# Epoch 66: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3637 - accuracy: 0.8430 - val_loss: 0.3822 - val_accuracy: 0.8601
# Epoch 67/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3679 - accuracy: 0.8440
# Epoch 67: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3676 - accuracy: 0.8442 - val_loss: 0.3670 - val_accuracy: 0.8632
# Epoch 68/150
# 523/563 [==========================>...] - ETA: 0s - loss: 0.3609 - accuracy: 0.8455
# Epoch 68: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3604 - accuracy: 0.8459 - val_loss: 0.3488 - val_accuracy: 0.8592
# Epoch 69/150
# 554/563 [============================>.] - ETA: 0s - loss: 0.3659 - accuracy: 0.8435
# Epoch 69: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3655 - accuracy: 0.8434 - val_loss: 0.3713 - val_accuracy: 0.8592
# Epoch 70/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3689 - accuracy: 0.8468
# Epoch 70: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3685 - accuracy: 0.8470 - val_loss: 0.3612 - val_accuracy: 0.8579
# Epoch 71/150
# 549/563 [============================>.] - ETA: 0s - loss: 0.3642 - accuracy: 0.8455
# Epoch 71: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3649 - accuracy: 0.8456 - val_loss: 0.3772 - val_accuracy: 0.8626
# Epoch 72/150
# 529/563 [===========================>..] - ETA: 0s - loss: 0.3652 - accuracy: 0.8457
# Epoch 72: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3643 - accuracy: 0.8463 - val_loss: 0.3826 - val_accuracy: 0.8595
# Epoch 73/150
# 527/563 [===========================>..] - ETA: 0s - loss: 0.3668 - accuracy: 0.8460
# Epoch 73: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3661 - accuracy: 0.8459 - val_loss: 0.3520 - val_accuracy: 0.8623
# Epoch 74/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3593 - accuracy: 0.8472
# Epoch 74: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3603 - accuracy: 0.8473 - val_loss: 0.3571 - val_accuracy: 0.8603
# Epoch 75/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3667 - accuracy: 0.8456
# Epoch 75: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3666 - accuracy: 0.8457 - val_loss: 0.3716 - val_accuracy: 0.8630
# Epoch 76/150
# 524/563 [==========================>...] - ETA: 0s - loss: 0.3652 - accuracy: 0.8460
# Epoch 76: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8472 - val_loss: 0.3456 - val_accuracy: 0.8663
# Epoch 77/150
# 532/563 [===========================>..] - ETA: 0s - loss: 0.3582 - accuracy: 0.8486
# Epoch 77: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3605 - accuracy: 0.8478 - val_loss: 0.3700 - val_accuracy: 0.8621
# Epoch 78/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3655 - accuracy: 0.8455
# Epoch 78: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3655 - accuracy: 0.8454 - val_loss: 0.3665 - val_accuracy: 0.8632
# Epoch 79/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3621 - accuracy: 0.8471
# Epoch 79: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3624 - accuracy: 0.8471 - val_loss: 0.3640 - val_accuracy: 0.8668
# Epoch 80/150
# 522/563 [==========================>...] - ETA: 0s - loss: 0.3598 - accuracy: 0.8499
# Epoch 80: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3614 - accuracy: 0.8489 - val_loss: 0.3804 - val_accuracy: 0.8599
# Epoch 81/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3641 - accuracy: 0.8468
# Epoch 81: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3640 - accuracy: 0.8469 - val_loss: 0.3749 - val_accuracy: 0.8590
# Epoch 82/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.3652 - accuracy: 0.8478
# Epoch 82: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3644 - accuracy: 0.8482 - val_loss: 0.3570 - val_accuracy: 0.8637
# Epoch 83/150
# 542/563 [===========================>..] - ETA: 0s - loss: 0.3668 - accuracy: 0.8439
# Epoch 83: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3659 - accuracy: 0.8447 - val_loss: 0.3472 - val_accuracy: 0.8672
# Epoch 84/150
# 545/563 [============================>.] - ETA: 0s - loss: 0.3608 - accuracy: 0.8464
# Epoch 84: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3619 - accuracy: 0.8460 - val_loss: 0.3830 - val_accuracy: 0.8601
# Epoch 85/150
# 524/563 [==========================>...] - ETA: 0s - loss: 0.3605 - accuracy: 0.8485
# Epoch 85: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3609 - accuracy: 0.8485 - val_loss: 0.3703 - val_accuracy: 0.8639
# Epoch 86/150
# 523/563 [==========================>...] - ETA: 0s - loss: 0.3638 - accuracy: 0.8478
# Epoch 86: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3668 - accuracy: 0.8456 - val_loss: 0.3693 - val_accuracy: 0.8559
# Epoch 87/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3553 - accuracy: 0.8471
# Epoch 87: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3552 - accuracy: 0.8470 - val_loss: 0.3715 - val_accuracy: 0.8648
# Epoch 88/150
# 524/563 [==========================>...] - ETA: 0s - loss: 0.3590 - accuracy: 0.8498
# Epoch 88: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3583 - accuracy: 0.8504 - val_loss: 0.3575 - val_accuracy: 0.8599
# Epoch 89/150
# 526/563 [===========================>..] - ETA: 0s - loss: 0.3569 - accuracy: 0.8498
# Epoch 89: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3576 - accuracy: 0.8494 - val_loss: 0.3668 - val_accuracy: 0.8610
# Epoch 90/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3607 - accuracy: 0.8499
# Epoch 90: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3607 - accuracy: 0.8499 - val_loss: 0.3610 - val_accuracy: 0.8694
# Epoch 91/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3634 - accuracy: 0.8477
# Epoch 91: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3633 - accuracy: 0.8476 - val_loss: 0.3671 - val_accuracy: 0.8643
# Epoch 92/150
# 524/563 [==========================>...] - ETA: 0s - loss: 0.3602 - accuracy: 0.8498
# Epoch 92: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3606 - accuracy: 0.8499 - val_loss: 0.3643 - val_accuracy: 0.8650
# Epoch 93/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3629 - accuracy: 0.8495
# Epoch 93: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3626 - accuracy: 0.8495 - val_loss: 0.3654 - val_accuracy: 0.8626
# Epoch 94/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3575 - accuracy: 0.8471
# Epoch 94: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3579 - accuracy: 0.8472 - val_loss: 0.3783 - val_accuracy: 0.8508
# Epoch 95/150
# 552/563 [============================>.] - ETA: 0s - loss: 0.3608 - accuracy: 0.8453
# Epoch 95: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3593 - accuracy: 0.8457 - val_loss: 0.3546 - val_accuracy: 0.8626
# Epoch 96/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3613 - accuracy: 0.8460
# Epoch 96: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3613 - accuracy: 0.8460 - val_loss: 0.3707 - val_accuracy: 0.8688
# Epoch 97/150
# 556/563 [============================>.] - ETA: 0s - loss: 0.3604 - accuracy: 0.8465
# Epoch 97: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3607 - accuracy: 0.8465 - val_loss: 0.3640 - val_accuracy: 0.8670
# Epoch 98/150
# 521/563 [==========================>...] - ETA: 0s - loss: 0.3539 - accuracy: 0.8512
# Epoch 98: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3559 - accuracy: 0.8501 - val_loss: 0.3619 - val_accuracy: 0.8621
# Epoch 99/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8496
# Epoch 99: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3581 - accuracy: 0.8500 - val_loss: 0.3711 - val_accuracy: 0.8650
# Epoch 100/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3590 - accuracy: 0.8483
# Epoch 100: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3586 - accuracy: 0.8481 - val_loss: 0.3558 - val_accuracy: 0.8599
# Epoch 101/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3596 - accuracy: 0.8502
# Epoch 101: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3599 - accuracy: 0.8501 - val_loss: 0.3716 - val_accuracy: 0.8683
# Epoch 102/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3566 - accuracy: 0.8506
# Epoch 102: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3565 - accuracy: 0.8505 - val_loss: 0.3515 - val_accuracy: 0.8615
# Epoch 103/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3576 - accuracy: 0.8514
# Epoch 103: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3578 - accuracy: 0.8512 - val_loss: 0.3686 - val_accuracy: 0.8675
# Epoch 104/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3601 - accuracy: 0.8511
# Epoch 104: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3599 - accuracy: 0.8512 - val_loss: 0.3678 - val_accuracy: 0.8619
# Epoch 105/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3606 - accuracy: 0.8482
# Epoch 105: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3610 - accuracy: 0.8481 - val_loss: 0.3697 - val_accuracy: 0.8646
# Epoch 106/150
# 555/563 [============================>.] - ETA: 0s - loss: 0.3584 - accuracy: 0.8499
# Epoch 106: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3580 - accuracy: 0.8500 - val_loss: 0.3620 - val_accuracy: 0.8626
# Epoch 107/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3560 - accuracy: 0.8506
# Epoch 107: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3562 - accuracy: 0.8507 - val_loss: 0.3641 - val_accuracy: 0.8666
# Epoch 108/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3582 - accuracy: 0.8514
# Epoch 108: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3581 - accuracy: 0.8514 - val_loss: 0.3577 - val_accuracy: 0.8617
# Epoch 109/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3527 - accuracy: 0.8526
# Epoch 109: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3526 - accuracy: 0.8525 - val_loss: 0.3498 - val_accuracy: 0.8679
# Epoch 110/150
# 554/563 [============================>.] - ETA: 0s - loss: 0.3593 - accuracy: 0.8494
# Epoch 110: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3588 - accuracy: 0.8497 - val_loss: 0.3542 - val_accuracy: 0.8657
# Epoch 111/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3566 - accuracy: 0.8513
# Epoch 111: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3566 - accuracy: 0.8513 - val_loss: 0.3620 - val_accuracy: 0.8679
# Epoch 112/150
# 534/563 [===========================>..] - ETA: 0s - loss: 0.3609 - accuracy: 0.8509
# Epoch 112: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3615 - accuracy: 0.8504 - val_loss: 0.3748 - val_accuracy: 0.8683
# Epoch 113/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3524 - accuracy: 0.8496
# Epoch 113: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3530 - accuracy: 0.8495 - val_loss: 0.3542 - val_accuracy: 0.8677
# Epoch 114/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3585 - accuracy: 0.8501
# Epoch 114: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3590 - accuracy: 0.8499 - val_loss: 0.3692 - val_accuracy: 0.8635
# Epoch 115/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3511 - accuracy: 0.8529
# Epoch 115: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3512 - accuracy: 0.8528 - val_loss: 0.3831 - val_accuracy: 0.8597
# Epoch 116/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3588 - accuracy: 0.8471
# Epoch 116: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3586 - accuracy: 0.8470 - val_loss: 0.3646 - val_accuracy: 0.8621
# Epoch 117/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3563 - accuracy: 0.8493
# Epoch 117: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3563 - accuracy: 0.8493 - val_loss: 0.3593 - val_accuracy: 0.8632
# Epoch 118/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3548 - accuracy: 0.8522
# Epoch 118: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3549 - accuracy: 0.8523 - val_loss: 0.3677 - val_accuracy: 0.8672
# Epoch 119/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3567 - accuracy: 0.8508
# Epoch 119: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3566 - accuracy: 0.8508 - val_loss: 0.3819 - val_accuracy: 0.8635
# Epoch 120/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3526 - accuracy: 0.8519
# Epoch 120: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3526 - accuracy: 0.8519 - val_loss: 0.3574 - val_accuracy: 0.8708
# Epoch 121/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3482 - accuracy: 0.8562
# Epoch 121: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3488 - accuracy: 0.8561 - val_loss: 0.3599 - val_accuracy: 0.8683
# Epoch 122/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3570 - accuracy: 0.8504
# Epoch 122: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3568 - accuracy: 0.8504 - val_loss: 0.3494 - val_accuracy: 0.8661
# Epoch 123/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3523 - accuracy: 0.8518
# Epoch 123: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3527 - accuracy: 0.8519 - val_loss: 0.3662 - val_accuracy: 0.8679
# Epoch 124/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3543 - accuracy: 0.8549
# Epoch 124: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3542 - accuracy: 0.8548 - val_loss: 0.3831 - val_accuracy: 0.8601
# Epoch 125/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3601 - accuracy: 0.8537
# Epoch 125: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3602 - accuracy: 0.8537 - val_loss: 0.3663 - val_accuracy: 0.8666
# Epoch 126/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3543 - accuracy: 0.8510
# Epoch 126: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3542 - accuracy: 0.8511 - val_loss: 0.3570 - val_accuracy: 0.8608
# Epoch 127/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3497 - accuracy: 0.8524
# Epoch 127: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3495 - accuracy: 0.8524 - val_loss: 0.3551 - val_accuracy: 0.8646
# Epoch 128/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3582 - accuracy: 0.8494
# Epoch 128: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3583 - accuracy: 0.8491 - val_loss: 0.3889 - val_accuracy: 0.8568
# Epoch 129/150
# 557/563 [============================>.] - ETA: 0s - loss: 0.3508 - accuracy: 0.8550
# Epoch 129: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3505 - accuracy: 0.8552 - val_loss: 0.3601 - val_accuracy: 0.8666
# Epoch 130/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3532 - accuracy: 0.8500
# Epoch 130: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3539 - accuracy: 0.8495 - val_loss: 0.3551 - val_accuracy: 0.8639
# Epoch 131/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3538 - accuracy: 0.8535
# Epoch 131: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3535 - accuracy: 0.8537 - val_loss: 0.3690 - val_accuracy: 0.8668
# Epoch 132/150
# 554/563 [============================>.] - ETA: 0s - loss: 0.3537 - accuracy: 0.8510
# Epoch 132: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3536 - accuracy: 0.8517 - val_loss: 0.3657 - val_accuracy: 0.8663
# Epoch 133/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3613 - accuracy: 0.8475
# Epoch 133: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3612 - accuracy: 0.8477 - val_loss: 0.3570 - val_accuracy: 0.8619
# Epoch 134/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3580 - accuracy: 0.8482
# Epoch 134: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3584 - accuracy: 0.8481 - val_loss: 0.3483 - val_accuracy: 0.8652
# Epoch 135/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3505 - accuracy: 0.8538
# Epoch 135: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3507 - accuracy: 0.8536 - val_loss: 0.3526 - val_accuracy: 0.8681
# Epoch 136/150
# 563/563 [==============================] - ETA: 0s - loss: 0.3490 - accuracy: 0.8543
# Epoch 136: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3490 - accuracy: 0.8543 - val_loss: 0.3713 - val_accuracy: 0.8626
# Epoch 137/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3573 - accuracy: 0.8525
# Epoch 137: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3569 - accuracy: 0.8526 - val_loss: 0.3609 - val_accuracy: 0.8670
# Epoch 138/150
# 562/563 [============================>.] - ETA: 0s - loss: 0.3528 - accuracy: 0.8521
# Epoch 138: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3529 - accuracy: 0.8519 - val_loss: 0.3794 - val_accuracy: 0.8652
# Epoch 139/150
# 553/563 [============================>.] - ETA: 0s - loss: 0.3512 - accuracy: 0.8528
# Epoch 139: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3511 - accuracy: 0.8524 - val_loss: 0.3729 - val_accuracy: 0.8661
# Epoch 140/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3513 - accuracy: 0.8525
# Epoch 140: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3513 - accuracy: 0.8521 - val_loss: 0.3705 - val_accuracy: 0.8648
# Epoch 141/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3530 - accuracy: 0.8508
# Epoch 141: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3537 - accuracy: 0.8505 - val_loss: 0.3524 - val_accuracy: 0.8646
# Epoch 142/150
# 528/563 [===========================>..] - ETA: 0s - loss: 0.3513 - accuracy: 0.8554
# Epoch 142: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3531 - accuracy: 0.8546 - val_loss: 0.3698 - val_accuracy: 0.8655
# Epoch 143/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3527 - accuracy: 0.8501
# Epoch 143: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3536 - accuracy: 0.8498 - val_loss: 0.3765 - val_accuracy: 0.8630
# Epoch 144/150
# 561/563 [============================>.] - ETA: 0s - loss: 0.3496 - accuracy: 0.8533
# Epoch 144: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3494 - accuracy: 0.8533 - val_loss: 0.3444 - val_accuracy: 0.8652
# Epoch 145/150
# 560/563 [============================>.] - ETA: 0s - loss: 0.3507 - accuracy: 0.8537
# Epoch 145: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3504 - accuracy: 0.8538 - val_loss: 0.3574 - val_accuracy: 0.8643
# Epoch 146/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3555 - accuracy: 0.8497
# Epoch 146: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3555 - accuracy: 0.8496 - val_loss: 0.3508 - val_accuracy: 0.8659
# Epoch 147/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3527 - accuracy: 0.8509
# Epoch 147: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3526 - accuracy: 0.8512 - val_loss: 0.3787 - val_accuracy: 0.8630
# Epoch 148/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3549 - accuracy: 0.8531
# Epoch 148: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3547 - accuracy: 0.8531 - val_loss: 0.3486 - val_accuracy: 0.8677
# Epoch 149/150
# 559/563 [============================>.] - ETA: 0s - loss: 0.3496 - accuracy: 0.8531
# Epoch 149: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3496 - accuracy: 0.8531 - val_loss: 0.3565 - val_accuracy: 0.8646
# Epoch 150/150
# 558/563 [============================>.] - ETA: 0s - loss: 0.3554 - accuracy: 0.8512
# Epoch 150: val_loss did not improve from 0.34110
# 563/563 [==============================] - 1s 1ms/step - loss: 0.3551 - accuracy: 0.8512 - val_loss: 0.3572 - val_accuracy: 0.8699
# Training completed in time:  0:01:55.635202

# %%
test_accuracy=model.evaluate(X_test,y_test,verbose=0)
print(test_accuracy[1])
# Out:
# 0.8698934316635132
